# %%
# %run Otsu_Final.ipynb
# Out:
# 125
# 125
# Elapsed time: 18122.383 µs
# Elapsed time: 7840.872 µs

# %%
# %run Histogram_Final.ipynb
# Out:
# 103.30500158906722
# 103.30500158906722
# 103.30500158906722

# %%
# %run Depth_based_Extraction_Final.ipynb
# Out:
# (512, 512)
# <class 'PIL.PngImagePlugin.PngImageFile'>

# %%
# %run Connected_component_analysis_Final.ipynb
